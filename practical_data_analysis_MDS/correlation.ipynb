# %%
import pandas as pd
data = pd.read_csv('correlation.csv')
data.head()
# Out:
#    Day_No  Temp  Cold_Drink  Hot_Drink  Snacks
# 0       1    35         120        175      45
# 1       2    35         122        170      50
# 2       3    36         125        172      51
# 3       4    36         130        170      52
# 4       5    35         128        177      45

# %%
data.describe()
# Out:
#            Day_No        Temp  Cold_Drink   Hot_Drink      Snacks
# count  120.000000  120.000000  120.000000  120.000000  120.000000
# mean    60.500000   38.533333  141.750000  128.766667   50.066667
# std     34.785054    2.315216   13.111833   19.615948    2.946963
# min      1.000000   34.000000  115.000000  109.000000   45.000000
# 25%     30.750000   36.000000  130.000000  114.750000   48.000000
# 50%     60.500000   39.000000  145.000000  120.000000   51.000000
# 75%     90.250000   40.000000  151.000000  139.250000   52.000000
# max    120.000000   42.000000  162.000000  177.000000   56.000000

# %%
data.corr(method='pearson', min_periods=1)
# Out:
#               Day_No      Temp  Cold_Drink  Hot_Drink    Snacks
# Day_No      1.000000  0.269834    0.378274  -0.468887  0.045251
# Temp        0.269834  1.000000    0.890255  -0.734043 -0.021266
# Cold_Drink  0.378274  0.890255    1.000000  -0.756659  0.042191
# Hot_Drink  -0.468887 -0.734043   -0.756659   1.000000 -0.100323
# Snacks      0.045251 -0.021266    0.042191  -0.100323  1.000000

# %%
data.corr(method='kendall', min_periods=1)
# Out:
#               Day_No      Temp  Cold_Drink  Hot_Drink    Snacks
# Day_No      1.000000  0.189172    0.275782  -0.341609  0.009087
# Temp        0.189172  1.000000    0.736854  -0.551354 -0.033551
# Cold_Drink  0.275782  0.736854    1.000000  -0.511530  0.025593
# Hot_Drink  -0.341609 -0.551354   -0.511530   1.000000 -0.036256
# Snacks      0.009087 -0.033551    0.025593  -0.036256  1.000000

# %%
data.corr(method='spearman', min_periods=1)
# Out:
#               Day_No      Temp  Cold_Drink  Hot_Drink    Snacks
# Day_No      1.000000  0.264297    0.380530  -0.457385  0.009190
# Temp        0.264297  1.000000    0.870657  -0.690304 -0.043479
# Cold_Drink  0.380530  0.870657    1.000000  -0.686986  0.029932
# Hot_Drink  -0.457385 -0.690304   -0.686986   1.000000 -0.045372
# Snacks      0.009190 -0.043479    0.029932  -0.045372  1.000000

# %%
data[['Temp', 'Cold_Drink']].corr()
# Out:
#                 Temp  Cold_Drink
# Temp        1.000000    0.890255
# Cold_Drink  0.890255    1.000000

# %%
data[['Temp', 'Hot_Drink']].corr()
# Out:
#                Temp  Hot_Drink
# Temp       1.000000  -0.734043
# Hot_Drink -0.734043   1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5651e_row0_col0, #T_5651e_row1_col1, #T_5651e_row2_col2, #T_5651e_row3_col3, #T_5651e_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5651e_row0_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_5651e_row0_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_5651e_row0_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_5651e_row0_col4, #T_5651e_row2_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_5651e_row1_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_5651e_row1_col2 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_5651e_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_5651e_row1_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_5651e_row2_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_5651e_row2_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_5651e_row2_col3, #T_5651e_row3_col0, #T_5651e_row3_col1, #T_5651e_row3_col2, #T_5651e_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5651e_row4_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_5651e_row4_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_5651e_row4_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5651e_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_5651e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5651e_level0_col0" class="col_heading level0 col0" >Day_No</th>
#       <th id="T_5651e_level0_col1" class="col_heading level0 col1" >Temp</th>
#       <th id="T_5651e_level0_col2" class="col_heading level0 col2" >Cold_Drink</th>
#       <th id="T_5651e_level0_col3" class="col_heading level0 col3" >Hot_Drink</th>
#       <th id="T_5651e_level0_col4" class="col_heading level0 col4" >Snacks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5651e_level0_row0" class="row_heading level0 row0" >Day_No</th>
#       <td id="T_5651e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5651e_row0_col1" class="data row0 col1" >0.269834</td>
#       <td id="T_5651e_row0_col2" class="data row0 col2" >0.378274</td>
#       <td id="T_5651e_row0_col3" class="data row0 col3" >-0.468887</td>
#       <td id="T_5651e_row0_col4" class="data row0 col4" >0.045251</td>
#     </tr>
#     <tr>
#       <th id="T_5651e_level0_row1" class="row_heading level0 row1" >Temp</th>
#       <td id="T_5651e_row1_col0" class="data row1 col0" >0.269834</td>
#       <td id="T_5651e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5651e_row1_col2" class="data row1 col2" >0.890255</td>
#       <td id="T_5651e_row1_col3" class="data row1 col3" >-0.734043</td>
#       <td id="T_5651e_row1_col4" class="data row1 col4" >-0.021266</td>
#     </tr>
#     <tr>
#       <th id="T_5651e_level0_row2" class="row_heading level0 row2" >Cold_Drink</th>
#       <td id="T_5651e_row2_col0" class="data row2 col0" >0.378274</td>
#       <td id="T_5651e_row2_col1" class="data row2 col1" >0.890255</td>
#       <td id="T_5651e_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5651e_row2_col3" class="data row2 col3" >-0.756659</td>
#       <td id="T_5651e_row2_col4" class="data row2 col4" >0.042191</td>
#     </tr>
#     <tr>
#       <th id="T_5651e_level0_row3" class="row_heading level0 row3" >Hot_Drink</th>
#       <td id="T_5651e_row3_col0" class="data row3 col0" >-0.468887</td>
#       <td id="T_5651e_row3_col1" class="data row3 col1" >-0.734043</td>
#       <td id="T_5651e_row3_col2" class="data row3 col2" >-0.756659</td>
#       <td id="T_5651e_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5651e_row3_col4" class="data row3 col4" >-0.100323</td>
#     </tr>
#     <tr>
#       <th id="T_5651e_level0_row4" class="row_heading level0 row4" >Snacks</th>
#       <td id="T_5651e_row4_col0" class="data row4 col0" >0.045251</td>
#       <td id="T_5651e_row4_col1" class="data row4 col1" >-0.021266</td>
#       <td id="T_5651e_row4_col2" class="data row4 col2" >0.042191</td>
#       <td id="T_5651e_row4_col3" class="data row4 col3" >-0.100323</td>
#       <td id="T_5651e_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
data.corr().style.background_gradient(cmap='coolwarm').format("{:.2f}")
# Out:
# <style type="text/css">
# #T_200b4_row0_col0, #T_200b4_row1_col1, #T_200b4_row2_col2, #T_200b4_row3_col3, #T_200b4_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_200b4_row0_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_200b4_row0_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_200b4_row0_col3 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_200b4_row0_col4, #T_200b4_row2_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_200b4_row1_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_200b4_row1_col2 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_200b4_row1_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_200b4_row1_col4 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_200b4_row2_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_200b4_row2_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_200b4_row2_col3, #T_200b4_row3_col0, #T_200b4_row3_col1, #T_200b4_row3_col2, #T_200b4_row3_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_200b4_row4_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_200b4_row4_col1 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_200b4_row4_col2 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_200b4_row4_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_200b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_200b4_level0_col0" class="col_heading level0 col0" >Day_No</th>
#       <th id="T_200b4_level0_col1" class="col_heading level0 col1" >Temp</th>
#       <th id="T_200b4_level0_col2" class="col_heading level0 col2" >Cold_Drink</th>
#       <th id="T_200b4_level0_col3" class="col_heading level0 col3" >Hot_Drink</th>
#       <th id="T_200b4_level0_col4" class="col_heading level0 col4" >Snacks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_200b4_level0_row0" class="row_heading level0 row0" >Day_No</th>
#       <td id="T_200b4_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_200b4_row0_col1" class="data row0 col1" >0.27</td>
#       <td id="T_200b4_row0_col2" class="data row0 col2" >0.38</td>
#       <td id="T_200b4_row0_col3" class="data row0 col3" >-0.47</td>
#       <td id="T_200b4_row0_col4" class="data row0 col4" >0.05</td>
#     </tr>
#     <tr>
#       <th id="T_200b4_level0_row1" class="row_heading level0 row1" >Temp</th>
#       <td id="T_200b4_row1_col0" class="data row1 col0" >0.27</td>
#       <td id="T_200b4_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_200b4_row1_col2" class="data row1 col2" >0.89</td>
#       <td id="T_200b4_row1_col3" class="data row1 col3" >-0.73</td>
#       <td id="T_200b4_row1_col4" class="data row1 col4" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_200b4_level0_row2" class="row_heading level0 row2" >Cold_Drink</th>
#       <td id="T_200b4_row2_col0" class="data row2 col0" >0.38</td>
#       <td id="T_200b4_row2_col1" class="data row2 col1" >0.89</td>
#       <td id="T_200b4_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_200b4_row2_col3" class="data row2 col3" >-0.76</td>
#       <td id="T_200b4_row2_col4" class="data row2 col4" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_200b4_level0_row3" class="row_heading level0 row3" >Hot_Drink</th>
#       <td id="T_200b4_row3_col0" class="data row3 col0" >-0.47</td>
#       <td id="T_200b4_row3_col1" class="data row3 col1" >-0.73</td>
#       <td id="T_200b4_row3_col2" class="data row3 col2" >-0.76</td>
#       <td id="T_200b4_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_200b4_row3_col4" class="data row3 col4" >-0.10</td>
#     </tr>
#     <tr>
#       <th id="T_200b4_level0_row4" class="row_heading level0 row4" >Snacks</th>
#       <td id="T_200b4_row4_col0" class="data row4 col0" >0.05</td>
#       <td id="T_200b4_row4_col1" class="data row4 col1" >-0.02</td>
#       <td id="T_200b4_row4_col2" class="data row4 col2" >0.04</td>
#       <td id="T_200b4_row4_col3" class="data row4 col3" >-0.10</td>
#       <td id="T_200b4_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.scatter(data['Temp'], data['Cold_Drink'])
plt.show()

# %%
plt.scatter(data['Temp'], data['Hot_Drink'])
plt.show()

# %%
plt.scatter(data['Temp'], data['Snacks'])
plt.show()
