# %% [markdown]
# ### Data Cleaning
# [Link](https://www.youtube.com/watch?v=FrLhfeiyha0&list=PLD_eiqVVLZDj1onVQPuREzf90xRT2WIdR&index=27)

# %%
import pandas as pd
data = pd.read_csv('sample-clean.csv')
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000     169
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %% [markdown]
# ### Simple Feature Scaling

# %% [markdown]
# $\displaystyle \text{Normalized Value} = \frac{\text{Old Value}}{\text{Maximum Value}}$

# %%
data['height'].max()
# Out:
# 195

# %%
data['height'].min()
# Out:
# 149

# %%
data['height'] = data['height'] / data['height'].max()
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary    height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000  0.846154
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000  0.794872
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000  0.810256
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000  0.764103
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000  0.866667
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %% [markdown]
# ### Min-Max Normalization

# %% [markdown]
# $\displaystyle \text{Normalized Value} = \frac{\text{Old Value - Min Value}}{\text{Max Value - Min Value}}$

# %%
data['weight'] = (data['weight'] - data['weight'].min())/(data['weight'].max() - data['weight'].min())
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary    height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000  0.846154
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000  0.794872
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000  0.810256
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000  0.764103
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000  0.866667
#
#     weight  birth_place
# 0  0.46875           NY
# 1  0.31250      Chicago
# 2  0.81250  Los Angeles
# 3  0.87500  Los Angeles
# 4  0.78125           LA

# %% [markdown]
# ### Z-score Normalization

# %% [markdown]
# $\displaystyle \text{Normalized Value} = \frac{\text{Old Value - Mean}(\mu)}{STD (\sigma)}$

# %%
data.describe()
# Out:
#            emp_id         salary      height     weight
# count  100.000000     100.000000  100.000000  78.000000
# mean    50.500000  325200.000000    0.858718   0.491987
# std     29.011492  193294.039894    0.046090   0.247473
# min      1.000000  120000.000000    0.764103   0.000000
# 25%     25.750000  200000.000000    0.820513   0.312500
# 50%     50.500000  300000.000000    0.861538   0.500000
# 75%     75.250000  400000.000000    0.888462   0.679688
# max    100.000000  750000.000000    1.000000   1.000000

# %%
data['salary'] = (data['salary'] - data['salary'].mean()) / data['salary'].std()
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date    salary  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  0.904322
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85 -1.061595
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  0.128302
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  0.386975
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89 -0.647718
#
#      height   weight  birth_place
# 0  0.846154  0.46875           NY
# 1  0.794872  0.31250      Chicago
# 2  0.810256  0.81250  Los Angeles
# 3  0.764103  0.87500  Los Angeles
# 4  0.866667  0.78125           LA

# %% [markdown]
# row number 2 ရဲ့ salary က **အနုတ်**နဲ့ပြနေတာက မူလတန်ဖိုးကိုယ်တိုင်က mean ထက်နည်းနေတဲ့အတွက် negative value ဘက်ရောက်နေတယ်လို့ပြောလို့ရပါတယ်။

# %% [markdown]
# ### One-hot Encoding

# %%
pd.get_dummies(data, columns=['gender'])
# Out:
#     emp_id birth_date   first_name    last_name hire_date    salary    height  \
# 0        1   02-09-53       Georgi      Facello  26-06-86  0.904322  0.846154
# 1        2   02-06-64      Bezalel       Simmel  21-11-85 -1.061595  0.794872
# 2        3   03-12-59        Parto      Bamford  28-08-86  0.128302  0.810256
# 3        4   01-05-54    Chirstian      Koblick  01-12-86  0.386975  0.764103
# 4        5   21-01-55      Kyoichi     Maliniak  12-09-89 -0.647718  0.866667
# ..     ...        ...          ...          ...       ...       ...       ...
# 95      96   16-09-54       Jayson      Mandell  14-01-90  2.197688  0.887179
# 96      97   27-02-52        Remzi  Waschkowski  15-09-90 -0.647718  0.876923
# 97      98   23-09-61  Sreekrishna    Servieres  13-05-85  0.386975  0.810256
# 98      99   25-05-56       Valter      Sullins  18-10-88 -0.647718  0.815385
# 99     100   21-04-53     Hironobu    Haraldson  21-09-87 -0.130371  0.815385
#
#      weight      birth_place  gender_F  gender_M
# 0   0.46875               NY     False      True
# 1   0.31250          Chicago      True     False
# 2   0.81250      Los Angeles     False      True
# 3   0.87500      Los Angeles     False      True
# 4   0.78125               LA     False      True
# ..      ...              ...       ...       ...
# 95  0.28125               LA     False      True
# 96      NaN          Chicago     False      True
# 97  0.40625         New York      True     False
# 98  0.75000          Houston      True     False
# 99  0.50000  Washington D.C.      True     False
#
# [100 rows x 11 columns]

# %% [markdown]
# ### Data Binning

# %%
data = pd.read_csv('sample-clean.csv')
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000     169
#
#    weight  birth_place
# 0    64.0           NY
# 1    59.0      Chicago
# 2    75.0  Los Angeles
# 3    77.0  Los Angeles
# 4    74.0           LA

# %%
import numpy as np
bins = np.linspace(data['salary'].min(), data['salary'].max(), 6)
bins
# Out:
# array([120000., 246000., 372000., 498000., 624000., 750000.])

# %%
bin_names = ['very low', 'low', 'average', 'high', 'very high']
data['salary_group'] = pd.cut(data['salary'], bins=bins, labels=bin_names, include_lowest=True)
data.head()
# Out:
#    emp_id birth_date first_name last_name gender hire_date  salary  height  \
# 0       1   02-09-53     Georgi   Facello      M  26-06-86  500000     165
# 1       2   02-06-64    Bezalel    Simmel      F  21-11-85  120000     155
# 2       3   03-12-59      Parto   Bamford      M  28-08-86  350000     158
# 3       4   01-05-54  Chirstian   Koblick      M  01-12-86  400000     149
# 4       5   21-01-55    Kyoichi  Maliniak      M  12-09-89  200000     169
#
#    weight  birth_place salary_group
# 0    64.0           NY         high
# 1    59.0      Chicago     very low
# 2    75.0  Los Angeles          low
# 3    77.0  Los Angeles      average
# 4    74.0           LA     very low
