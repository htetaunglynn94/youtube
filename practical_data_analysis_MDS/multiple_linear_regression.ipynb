# %% [markdown]
# # [Multiple Linear Regression](https://www.youtube.com/watch?v=ggeGjrG2Tmg&list=PLD_eiqVVLZDj1onVQPuREzf90xRT2WIdR&index=44)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('regression-one.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.rename(columns={'Life expectancy':'life_expect'}, inplace=True)
df.head()
# Out:
#        Country  Year      Status  life_expect  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
# 3  Afghanistan  2012  Developing         59.5            272.0             69
# 4  Afghanistan  2011  Developing         59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  ...    6.0
# 1     0.01               73.523582         62.0      492  ...   58.0
# 2     0.01               73.219243         64.0      430  ...   62.0
# 3     0.01               78.184215         67.0     2787  ...   67.0
# 4     0.01                7.097109         68.0     3013  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df = df.dropna()
df.head()
# Out:
#        Country  Year      Status  life_expect  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
# 3  Afghanistan  2012  Developing         59.5            272.0             69
# 4  Afghanistan  2011  Developing         59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  ...    6.0
# 1     0.01               73.523582         62.0      492  ...   58.0
# 2     0.01               73.219243         64.0      430  ...   62.0
# 3     0.01               78.184215         67.0     2787  ...   67.0
# 4     0.01                7.097109         68.0     3013  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df[df.isna().any(axis=1)] # check null values
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, life_expect, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles, BMI, under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness 1-19 years, thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'life_expect', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles', 'BMI', 'under-five deaths', 'Polio', 'Total expenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness 1-19 years',
#        'thinness 5-9 years', 'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
X = df[['GDP','Alcohol','BMI','Schooling']]
Y = df['life_expect']

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, Y)
# Out:
# LinearRegression()

# %% [markdown]
# $\hat y = b_0 + b_1 x_1 + b_2 x_2 + b_3 x_3 + b_4 x_4 + …$

# %%
lm.intercept_    # b_0 values
# Out:
# 42.85195668537605

# %%
lm.coef_         # b_1, b_2, b_3 and b_4 values
# Out:
# array([ 1.15265737e-04, -2.52732304e-01,  8.91904815e-02,  1.94339619e+00])

# %%
Yhat = lm.predict(X)

# %%
data = pd.DataFrame({'Actual': df['life_expect'], 'Predicted':Yhat})
data.head(10)
# Out:
#    Actual  Predicted
# 0    65.0  64.248614
# 1    59.9  64.012957
# 2    59.9  63.776218
# 3    59.5  63.541688
# 4    59.2  62.853093
# 5    58.8  62.281935
# 6    58.6  61.641938
# 7    58.1  61.195248
# 8    57.5  60.569755
# 9    57.3  59.928401

# %%
import seaborn as sns
axs = sns.distplot(df['life_expect'], hist=False, color='r', label='Actual')
sns.distplot(Yhat, hist=False, color='b', label='Fitted', ax=axs)
plt.title('Actual vs Fitted values for LE')
plt.xlabel('Age Range')
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_25131/37620648.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   axs = sns.distplot(df['life_expect'], hist=False, color='r', label='Actual')
# /tmp/ipykernel_25131/37620648.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
